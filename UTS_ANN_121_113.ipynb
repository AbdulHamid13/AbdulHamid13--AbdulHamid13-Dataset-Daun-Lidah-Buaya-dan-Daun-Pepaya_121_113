#   inflating: Lidah Buaya/021.jpg
#   inflating: Lidah Buaya/022.jpg
#   inflating: Lidah Buaya/023.jpg
#   inflating: Lidah Buaya/024.jpg
#   inflating: Lidah Buaya/025.jpg
#   inflating: Lidah Buaya/026.jpg
# ...

# %%
# Split Folder : Untuk Split Dataset pada Testing dan Training/Validation
# !pip install split_folders
import splitfolders

# %%
import splitfolders
# Dataset daun lidah buaya
input_folder = "/content/gdrive/MyDrive/UTS_AI/Dataset"
output = "/content/gdrive/MyDrive/UTS_AI/Model Dataset/Splitted"
splitfolders.ratio(input_folder, output = output, seed = 1337, ratio = (.9, .1)) 
# .9 -> 90% Training, .1-> 10% Validation.
# Data training : data yang digunakan untuk melatih model.
# Data validasi : digunakan untuk validasi epoch terakhir (untuk mengevaluasi model).
# Out:
# Copying files: 100 files [00:01, 68.46 files/s]

# %%
import os

train_dir = "/content/gdrive/MyDrive/UTS_AI/Model Dataset/Splitted/train"
val_dir = "/content/gdrive/MyDrive/UTS_AI/Model Dataset/Splitted/val"

Lidah_Buaya_train_path = train_dir + "/Lidah_Buaya"
Pepaya_train_path = train_dir + "/Pepaya"
Lidah_Buaya_val_path = val_dir + "/Lidah_Buaya"
Pepaya_val_path = val_dir + "/Pepaya"

Lidah_Buaya_len_train = len(os.listdir(Lidah_Buaya_train_path))
Pepaya_len_train = len(os.listdir(Pepaya_train_path))
Lidah_Buaya_len_val = len(os.listdir(Lidah_Buaya_val_path))
Pepaya_len_val = len(os.listdir(Pepaya_val_path))

print("Jumlah dataset training : ", Lidah_Buaya_len_train + Pepaya_len_train)
print("Jumlah dataset validasi : ", Lidah_Buaya_len_val + Pepaya_len_val)
print()
print("Jumlah train kelas Lidah_Buaya ", Lidah_Buaya_len_train)
print("Jumlah train kelas Pepaya : ", Pepaya_len_train)
print("Jumlah validasi kelas Lidah_Buaya : ", Lidah_Buaya_len_val)
print("Jumlah validasi kelas Pepaya : ", Pepaya_len_val)
# Out:
# Jumlah dataset training :  90
# Jumlah dataset validasi :  10
#
# Jumlah train kelas Lidah_Buaya  45
# Jumlah train kelas Pepaya :  45
# Jumlah validasi kelas Lidah_Buaya :  5
# Jumlah validasi kelas Pepaya :  5

# %%
train_Lidah_Buaya_fnames = os.listdir(Lidah_Buaya_train_path)
train_Pepaya_fnames = os.listdir(Pepaya_train_path)

print(train_Lidah_Buaya_fnames[:10])
print(train_Pepaya_fnames[:10])
# Out:
# ['003.jpg', '002.jpg', '021.jpg', '018.jpg', '049.jpg', '030.jpg', '009.jpg', '019.jpg', '032.jpg', '031.jpg']
# ['003.jpg', '002.jpg', '021.jpg', '018.jpg', '049.jpg', '030.jpg', '009.jpg', '019.jpg', '032.jpg', '031.jpg']

# %%
# import terlebih dahulu library yang diperlukan

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Parameter dari visualisasi dimana terdiri dari 4 kolom
nrows = 4
ncols = 4

# Inisialisasi nilai awal untuk melakukan iterasi
pic_index = 0

# %%
# Mengatur matplotlib fig, dan ukuran visualisasi ke 4x4 pics

fig = plt.gcf()
fig.set_size_inches(ncols*4, nrows*4)

pic_index += 8

next_Lidah_Buaya_pix = [os.path.join(Lidah_Buaya_train_path, fname)
                   for fname in train_Lidah_Buaya_fnames[pic_index-8:pic_index]
                  ]

next_Pepaya_pix = [os.path.join(Pepaya_train_path, fname)
                   for fname in train_Pepaya_fnames[pic_index-8:pic_index]
                  ]

for i, img_path in enumerate(next_Lidah_Buaya_pix+next_Pepaya_pix):
  # Menyeting subplot
  sp = plt.subplot(nrows, ncols, i + 1)
  # Tidak menampilkan axes (atau gridlines)
  sp.axis("off")

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(rescale = 1.0/255.)
val_datagen = ImageDataGenerator(rescale = 1.0/255.)


train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=2,
                                                    class_mode='binary',
                                                    target_size=(150, 150))


validation_generator = val_datagen.flow_from_directory(val_dir,
                                                    batch_size=2,
                                                    class_mode='binary',
                                                    target_size=(150, 150))
# Out:
# Found 90 images belonging to 3 classes.
# Found 10 images belonging to 3 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model

# %%
img_input = layers.Input(shape=(150, 150, 3)) # layer input
x = layers.Flatten()(img_input) 
x = layers.Dense(125, activation='relu')(x)
output = layers.Dense(1, activation='sigmoid')(x) # output layer dengan 1 neuron (binary)


model = Model(img_input, output)

# %%
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  flatten (Flatten)           (None, 67500)             0
#
#  dense (Dense)               (None, 125)               8437625
#
#  dense_1 (Dense)             (None, 1)                 126
#
# ...
# Total params: 8,437,751
# Trainable params: 8,437,751
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
model.compile(optimizer=RMSprop(lr=1e-4), 
              loss='binary_crossentropy', 
              metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=45,  # images = batch_size * steps
      epochs=45,
      validation_data=validation_generator,
      validation_steps=5,  #  images = batch_size * steps
)
# Out:
# Epoch 1/45
# 45/45 [==============================] - 4s 30ms/step - loss: -288.4580 - acc: 0.5000 - val_loss: -579.7127 - val_acc: 0.5000
# Epoch 2/45
# 45/45 [==============================] - 1s 23ms/step - loss: -762.2637 - acc: 0.5000 - val_loss: -1103.0906 - val_acc: 0.5000
# Epoch 3/45
# 45/45 [==============================] - 1s 24ms/step - loss: -1275.3959 - acc: 0.5000 - val_loss: -1669.4203 - val_acc: 0.5000
# Epoch 4/45
# 45/45 [==============================] - 1s 24ms/step - loss: -1795.9445 - acc: 0.5000 - val_loss: -2239.4448 - val_acc: 0.5000
# Epoch 5/45
# 45/45 [==============================] - 1s 25ms/step - loss: -2306.2297 - acc: 0.5000 - val_loss: -2799.4946 - val_acc: 0.5000
# Epoch 6/45
# 45/45 [==============================] - 1s 26ms/step - loss: -2869.1013 - acc: 0.5000 - val_loss: -3447.0828 - val_acc: 0.5000
# Epoch 7/45
# 45/45 [==============================] - 1s 25ms/step - loss: -3467.1169 - acc: 0.5000 - val_loss: -4073.0344 - val_acc: 0.5000
# ...

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = history.history['acc']
val_acc  = history.history['val_acc']
loss     = history.history['loss']
val_loss = history.history['val_loss']

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs,     acc )
plt.plot  ( epochs, val_acc )
plt.title ('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs,     loss )
plt.plot  ( epochs, val_loss )
plt.title ('Training and validation loss'   )
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, recall_score, accuracy_score
from sklearn.metrics import precision_score, confusion_matrix, classification_report
import seaborn as sns
import numpy as np
sns.set(style='whitegrid')

# %%
def my_metrics(y_true, y_pred):
    accuracy=accuracy_score(y_true, y_pred)
    precision=precision_score(y_true, y_pred,average='weighted')
    f1Score=f1_score(y_true, y_pred, average='weighted') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("f1Score : {}".format(f1Score))
    cm=confusion_matrix(y_true, y_pred)
    print(cm)
    return accuracy, precision, f1Score


predictions = model.predict_generator(generator=validation_generator)
yPredictions = predictions > 0.5
true_classes = validation_generator.classes
class_names = validation_generator.class_indices
Cmatrix_test = confusion_matrix(true_classes, yPredictions)

testAcc,testPrec, testFScore = my_metrics(true_classes, yPredictions)

plt.figure(figsize=(20,20))
ax= plt.subplot()
data = np.asarray(Cmatrix_test).reshape(2,2)
sns.heatmap(data,annot=True, fmt='',ax=ax, cmap=plt.cm.Reds)
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(class_names)   
ax.yaxis.set_ticklabels(class_names)
plt.title('Confusion Matrix Test',fontsize=14)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy  : 0.5
# Precision : 0.25
# f1Score : 0.3333333333333333
# [[5 0]
#  [5 0]]

# %%
from sklearn.metrics import classification_report
print(classification_report(true_classes, yPredictions, target_names=class_names))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-adf25ea5c3cd> in <module>()
#       1 from sklearn.metrics import classification_report
# ----> 2 print(classification_report(true_classes, yPredictions, target_names=class_names))
#
# NameError: name 'true_classes' is not defined

# %%
model.save("/content/gdrive/MyDrive/UTS_AI/Dataset")
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/UTS_AI/Dataset/assets

# %%
# loading model to evaluate more depth
from keras.models import load_model
model_path = '/content/gdrive/MyDrive/UTS_AI/Dataset'

from google.colab import files
from keras.preprocessing import image

uploaded=files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path= fn
  img=image.load_img(path, target_size=(150, 150))
  
  x=image.img_to_array(img)
  x=np.expand_dims(x, axis=0)
  images = np.vstack([x])
  
  classes = model.predict(images, batch_size=10)
  
  print(classes[0])
  
  if classes[0]>0:
    print(fn + " ini adalah daun_Lidah Buaya")
    
  else:
    print(fn + " ini adalah daun_Pepaya")
 
model = load_model(model_path)
# Out:
#      <input type="file" id="files-00b56a0b-57a1-4b4f-a143-7e338b84197e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00b56a0b-57a1-4b4f-a143-7e338b84197e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-b3aedf27feb6> in <module>()
#       6 from keras.preprocessing import image
#       7
# ----> 8 uploaded=files.upload()
#       9
#      10 for fn in uploaded.keys():
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      61   result = _output.eval_js(
#      62       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ...
